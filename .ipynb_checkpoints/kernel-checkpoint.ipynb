# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20,20
sns.set(rc={'figure.figsize':(30,30)})

# %%
pkmn = pd.read_csv('data/Pokemon.csv')

# %%
pkmn = pkmn.drop(['Generation', 'isLegendary'],axis = 1)

# %%
pkmn
# Out:
#      Number        Name    Type_1  Type_2  Total   HP  Attack  Defense  \
# 0         1   Bulbasaur     Grass  Poison    318   45      49       49
# 1         2     Ivysaur     Grass  Poison    405   60      62       63
# 2         3    Venusaur     Grass  Poison    525   80      82       83
# 3         4  Charmander      Fire     NaN    309   39      52       43
# 4         5  Charmeleon      Fire     NaN    405   58      64       58
# 5         6   Charizard      Fire  Flying    534   78      84       78
# 6         7    Squirtle     Water     NaN    314   44      48       65
# 7         8   Wartortle     Water     NaN    405   59      63       80
# 8         9   Blastoise     Water     NaN    530   79      83      100
# 9        10    Caterpie       Bug     NaN    195   45      30       35
# 10       11     Metapod       Bug     NaN    205   50      20       55
# 11       12  Butterfree       Bug  Flying    395   60      45       50
# 12       13      Weedle       Bug  Poison    195   40      35       30
# 13       14      Kakuna       Bug  Poison    205   45      25       50
# 14       15    Beedrill       Bug  Poison    395   65      90       40
# 15       16      Pidgey    Normal  Flying    251   40      45       40
# 16       17   Pidgeotto    Normal  Flying    349   63      60       55
# 17       18     Pidgeot    Normal  Flying    479   83      80       75
# 18       19     Rattata    Normal     NaN    253   30      56       35
# 19       20    Raticate    Normal     NaN    413   55      81       60
# 20       21     Spearow    Normal  Flying    262   40      60       30
# 21       22      Fearow    Normal  Flying    442   65      90       65
# 22       23       Ekans    Poison     NaN    288   35      60       44
# 23       24       Arbok    Poison     NaN    438   60      85       69
# 24       25     Pikachu  Electric     NaN    320   35      55       40
# 25       26      Raichu  Electric     NaN    485   60      90       55
# 26       27   Sandshrew    Ground     NaN    300   50      75       85
# 27       28   Sandslash    Ground     NaN    450   75     100      110
# 28       29    Nidoran♀    Poison     NaN    275   55      47       52
# 29       30    Nidorina    Poison     NaN    365   70      62       67
# ..      ...         ...       ...     ...    ...  ...     ...      ...
# 691     692   Clauncher     Water     NaN    330   50      53       62
# 692     693   Clawitzer     Water     NaN    500   71      73       88
# 693     694  Helioptile  Electric  Normal    289   44      38       33
# 694     695   Heliolisk  Electric  Normal    481   62      55       52
# 695     696      Tyrunt      Rock  Dragon    362   58      89       77
# 696     697   Tyrantrum      Rock  Dragon    521   82     121      119
# 697     698      Amaura      Rock     Ice    362   77      59       50
# 698     699     Aurorus      Rock     Ice    521  123      77       72
# 699     700     Sylveon     Fairy     NaN    525   95      65       65
# 700     701    Hawlucha  Fighting  Flying    500   78      92       75
# 701     702     Dedenne  Electric   Fairy    431   67      58       57
# 702     703     Carbink      Rock   Fairy    500   50      50      150
# 703     704       Goomy    Dragon     NaN    300   45      50       35
# 704     705     Sliggoo    Dragon     NaN    452   68      75       53
# 705     706      Goodra    Dragon     NaN    600   90     100       70
# 706     707      Klefki     Steel   Fairy    470   57      80       91
# 707     708    Phantump     Ghost   Grass    309   43      70       48
# 708     709   Trevenant     Ghost   Grass    474   85     110       76
# 709     710   Pumpkaboo     Ghost   Grass    335   49      66       70
# 710     711   Gourgeist     Ghost   Grass    494   65      90      122
# 711     712    Bergmite       Ice     NaN    304   55      69       85
# 712     713     Avalugg       Ice     NaN    514   95     117      184
# 713     714      Noibat    Flying  Dragon    245   40      30       35
# 714     715     Noivern    Flying  Dragon    535   85      70       80
# 715     716     Xerneas     Fairy     NaN    680  126     131       95
# 716     717     Yveltal      Dark  Flying    680  126     131       95
# 717     718     Zygarde    Dragon  Ground    600  108     100      121
# 718     719     Diancie      Rock   Fairy    600   50     100      150
# 719     720       Hoopa   Psychic   Ghost    600   80     110       60
# 720     721   Volcanion      Fire   Water    600   80     110      120
#
#      Sp_Atk  Sp_Def        ...          Color hasGender  Pr_Male  \
# 0        65      65        ...          Green      True    0.875
# 1        80      80        ...          Green      True    0.875
# 2       100     100        ...          Green      True    0.875
# 3        60      50        ...            Red      True    0.875
# 4        80      65        ...            Red      True    0.875
# 5       109      85        ...            Red      True    0.875
# 6        50      64        ...           Blue      True    0.875
# 7        65      80        ...           Blue      True    0.875
# 8        85     105        ...           Blue      True    0.875
# 9        20      20        ...          Green      True    0.500
# 10       25      25        ...          Green      True    0.500
# 11       90      80        ...          White      True    0.500
# 12       20      20        ...          Brown      True    0.500
# 13       25      25        ...         Yellow      True    0.500
# 14       45      80        ...         Yellow      True    0.500
# 15       35      35        ...          Brown      True    0.500
# 16       50      50        ...          Brown      True    0.500
# 17       70      70        ...          Brown      True    0.500
# 18       25      35        ...         Purple      True    0.500
# 19       50      70        ...          Brown      True    0.500
# 20       31      31        ...          Brown      True    0.500
# 21       61      61        ...          Brown      True    0.500
# 22       40      54        ...         Purple      True    0.500
# 23       65      79        ...         Purple      True    0.500
# 24       50      50        ...         Yellow      True    0.500
# 25       90      80        ...         Yellow      True    0.500
# 26       20      30        ...         Yellow      True    0.500
# 27       45      55        ...         Yellow      True    0.500
# 28       40      40        ...           Blue      True    0.000
# 29       55      55        ...           Blue      True    0.000
# ..      ...     ...        ...            ...       ...      ...
# 691      58      63        ...           Blue      True    0.500
# 692     120      89        ...           Blue      True    0.500
# 693      61      43        ...         Yellow      True    0.500
# 694     109      94        ...         Yellow      True    0.500
# 695      45      45        ...          Brown      True    0.875
# 696      69      59        ...            Red      True    0.875
# 697      67      63        ...           Blue      True    0.875
# 698      99      92        ...           Blue      True    0.875
# 699     110     130        ...           Pink      True    0.875
# 700      74      63        ...          Green      True    0.500
# 701      81      67        ...         Yellow      True    0.500
# 702      50     150        ...           Grey     False      NaN
# 703      55      75        ...         Purple      True    0.500
# 704      83     113        ...         Purple      True    0.500
# 705     110     150        ...         Purple      True    0.500
# 706      80      87        ...           Grey      True    0.500
# 707      50      60        ...          Brown      True    0.500
# 708      65      82        ...          Brown      True    0.500
# 709      44      55        ...          Brown      True    0.500
# 710      58      75        ...          Brown      True    0.500
# 711      32      35        ...           Blue      True    0.500
# 712      44      46        ...           Blue      True    0.500
# 713      45      40        ...         Purple      True    0.500
# 714      97      80        ...         Purple      True    0.500
# 715     131      98        ...           Blue     False      NaN
# 716     131      98        ...            Red     False      NaN
# 717      81      95        ...          Green     False      NaN
# 718     100     150        ...           Pink     False      NaN
# 719     150     130        ...         Purple     False      NaN
# 720     130      90        ...          Brown     False      NaN
#
#       Egg_Group_1 Egg_Group_2 hasMegaEvolution  Height_m  Weight_kg  \
# 0         Monster       Grass            False      0.71        6.9
# 1         Monster       Grass            False      0.99       13.0
# 2         Monster       Grass             True      2.01      100.0
# 3         Monster      Dragon            False      0.61        8.5
# 4         Monster      Dragon            False      1.09       19.0
# 5         Monster      Dragon             True      1.70       90.5
# 6         Monster     Water_1            False      0.51        9.0
# 7         Monster     Water_1            False      0.99       22.5
# 8         Monster     Water_1             True      1.60       85.5
# 9             Bug         NaN            False      0.30        2.9
# 10            Bug         NaN            False      0.71        9.9
# 11            Bug         NaN            False      1.09       32.0
# 12            Bug         NaN            False      0.30        3.2
# 13            Bug         NaN            False      0.61       10.0
# 14            Bug         NaN             True      0.99       29.5
# 15         Flying         NaN            False      0.30        1.8
# 16         Flying         NaN            False      1.09       30.0
# 17         Flying         NaN             True      1.50       39.5
# 18          Field         NaN            False      0.30        3.5
# 19          Field         NaN            False      0.71       18.5
# 20         Flying         NaN            False      0.30        2.0
# 21         Flying         NaN            False      1.19       38.0
# 22          Field      Dragon            False      2.01        6.9
# 23          Field      Dragon            False      3.51       65.0
# 24          Field       Fairy            False      0.41        6.0
# 25          Field       Fairy            False      0.79       30.0
# 26          Field         NaN            False      0.61       12.0
# 27          Field         NaN            False      0.99       29.5
# 28        Monster       Field            False      0.41        7.0
# 29   Undiscovered         NaN            False      0.79       20.0
# ..            ...         ...              ...       ...        ...
# 691       Water_1     Water_3            False      0.51        8.3
# 692       Water_1     Water_3            False      1.30       35.3
# 693       Monster      Dragon            False      0.51        6.0
# 694       Monster      Dragon            False      0.99       21.0
# 695       Monster      Dragon            False      0.79       26.0
# 696       Monster      Dragon            False      2.49      270.0
# 697       Monster         NaN            False      1.30       25.2
# 698       Monster         NaN            False      2.69      225.0
# 699         Field         NaN            False      0.99       23.5
# 700    Human-Like         NaN            False      0.79       21.5
# 701         Field       Fairy            False      0.20        2.2
# 702         Fairy     Mineral            False      0.30        5.7
# 703        Dragon         NaN            False      0.30        2.8
# 704        Dragon         NaN            False      0.79       17.5
# 705        Dragon         NaN            False      2.01      150.5
# 706       Mineral         NaN            False      0.20        3.0
# 707         Grass   Amorphous            False      0.41        7.0
# 708         Grass   Amorphous            False      1.50       71.0
# 709     Amorphous         NaN            False      0.41        5.0
# 710     Amorphous         NaN            False      1.70       39.0
# 711       Monster         NaN            False      0.99       99.5
# 712       Monster         NaN            False      2.01      505.0
# 713        Flying         NaN            False      0.51        8.0
# 714        Flying         NaN            False      1.50       85.0
# 715  Undiscovered         NaN            False      3.00      215.0
# 716  Undiscovered         NaN            False      5.79      203.0
# 717  Undiscovered         NaN            False      5.00      305.0
# 718  Undiscovered         NaN             True      0.71        8.8
# 719  Undiscovered         NaN            False      0.51        9.0
# 720  Undiscovered         NaN            False      1.70      195.0
#
#      Catch_Rate        Body_Style
# 0            45         quadruped
# 1            45         quadruped
# 2            45         quadruped
# 3            45    bipedal_tailed
# 4            45    bipedal_tailed
# 5            45    bipedal_tailed
# 6            45    bipedal_tailed
# 7            45    bipedal_tailed
# 8            45    bipedal_tailed
# 9           255         insectoid
# 10          120   serpentine_body
# 11           45        four_wings
# 12          255   serpentine_body
# 13          120   serpentine_body
# 14           45        four_wings
# 15          255         two_wings
# 16          120         two_wings
# 17           45         two_wings
# 18          255         quadruped
# 19          127         quadruped
# 20          255         two_wings
# 21           90         two_wings
# 22          255   serpentine_body
# 23           90   serpentine_body
# 24          190         quadruped
# 25           75    bipedal_tailed
# 26          255    bipedal_tailed
# 27           90    bipedal_tailed
# 28          235         quadruped
# 29          120         quadruped
# ..          ...               ...
# 691         225         insectoid
# 692          55   serpentine_body
# 693         190    bipedal_tailed
# 694          75    bipedal_tailed
# 695          45    bipedal_tailed
# 696          45    bipedal_tailed
# 697          45         quadruped
# 698          45         quadruped
# 699          45         quadruped
# 700         100  bipedal_tailless
# 701         180    bipedal_tailed
# 702          60         head_only
# 703          45   serpentine_body
# 704          45   serpentine_body
# 705          45    bipedal_tailed
# 706          75         head_only
# 707         120         head_arms
# 708          60     several_limbs
# 709         120         head_only
# 710          60         head_base
# 711         190         quadruped
# 712          55         quadruped
# 713         190         two_wings
# 714          45         two_wings
# 715          45         quadruped
# 716          45         two_wings
# 717           3   serpentine_body
# 718           3         head_arms
# 719           3         head_only
# 720           3         quadruped
#
# [721 rows x 21 columns]

# %%
pkmn.mean(axis = 0)
# Out:
# Number              361.000000
# Total               417.945908
# HP                   68.380028
# Attack               75.013870
# Defense              70.808599
# Sp_Atk               68.737864
# Sp_Def               69.291262
# Speed                65.714286
# hasGender             0.893204
# Pr_Male               0.553377
# hasMegaEvolution      0.063800
# Height_m              1.144979
# Weight_kg            56.773370
# Catch_Rate          100.246879
# dtype: float64

# %%
sns.jointplot(x="HP", y="Weight_kg", data=pkmn ,height=10)

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data=pkmn)

# %%
pkmn = pkmn.drop(['Total','Number',"Body_Style",'Egg_Group_1','Egg_Group_2','hasMegaEvolution','hasGender','Color','Pr_Male'],axis = 1)

# min-max normalization
pkmn_norm = pkmn.drop(["Name", "Type_1", "Type_2"],axis = 1)
pkmn_norm = (pkmn_norm - pkmn_norm.min()) / (pkmn_norm.max() - pkmn_norm.min())

# %%
plt.figure(figsize=(15,10))
ax = sns.violinplot(data=pkmn_norm, inner=None)
ax = sns.swarmplot(data=pkmn_norm, edgecolor="gray")

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data=pkmn_norm)

# %%
pkmn = pkmn.drop(['HP','Attack',"Defense",'Sp_Atk','Sp_Def','Speed','Height_m','Weight_kg','Catch_Rate'],axis = 1)

# %%
pkmn_norm = pd.concat([pkmn, pkmn_norm], axis=1)
pkmn_norm = pd.melt(pkmn_norm, id_vars=["Name", "Type_1", "Type_2"], var_name="Stat")

# %%
sns.set_style("whitegrid")
with sns.color_palette([
    "#8ED752", "#F95643", "#53AFFE", "#C3D221", "#BBBDAF",
    "#AD5CA2", "#F8E64E", "#F0CA42", "#F9AEFE", "#A35449",
    "#FB61B4", "#CDBD72", "#7673DA", "#66EBFF", "#8B76FF",
    "#8E6856", "#C3C1D7", "#75A4F9"], n_colors=18, desat=.9):
    plt.figure(figsize=(12,10))
    plt.ylim(0, 1)
    sns.swarmplot(x="Stat", y="value", data=pkmn_norm, hue="Type_1", split=True, size=3)
    plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
# Out:
# /home/takitani/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
pkmn_norm_Type1 = pkmn_norm[pkmn_norm['Type_1'] == 'Grass']
pkmn_norm_Type2 = pkmn_norm[pkmn_norm['Type_1'] == 'Water']
pkmn_norm = pd.concat([pkmn_norm_Type1, pkmn_norm_Type2], axis=0)

# %%
sns.set_style("whitegrid")
with sns.color_palette([
    "#8ED752", "#F95643", "#53AFFE", "#C3D221", "#BBBDAF",
    "#AD5CA2", "#F8E64E", "#F0CA42", "#F9AEFE", "#A35449",
    "#FB61B4", "#CDBD72", "#7673DA", "#66EBFF", "#8B76FF",
    "#8E6856", "#C3C1D7", "#75A4F9"], n_colors=18, desat=.9):
    plt.figure(figsize=(12,10))
    plt.ylim(0, 1)
    sns.swarmplot(x="Stat", y="value", data=pkmn_norm, hue="Type_1", split=True, size=3)
    plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
# Out:
# /home/takitani/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
